# %% [markdown]
# Script to label object points.
#
# Adapted from P3PO - [link](https://github.com/mlevy2525/P3PO/blob/main/p3po/data_generation/label_points.ipynb)

# %%
# Run this the first time you use this notebook for point annotation
# This will install the necessary dependencies
# !pip install ipywidgets ipycanvas

# %%
import cv2
import pickle
from pathlib import Path

#TODO: Set the task name here -- this will be used to save the output
task_name = "close_oven"
object_name = "objects"

# If the image that shows at the bottom is bgr set original_bgr to True
pickle_path = "/home/akash/Projects/data/expert_demos/franka_env/bowl.pkl"
traj_idx = 0
original_bgr = True

#TODO: If its hard to see the image, you can increase the size_multiplier, this won't affect the selected coordinates
size_multiplier = 1

coordinates_path = f"../../../coordinates/{task_name}"

# %%
# %gui asyncio

import os
from PIL import Image

import numpy as np
from IPython.display import display, Javascript
import ipywidgets as widgets
from ipycanvas import Canvas, hold_canvas
import pickle

import io
import asyncio
import logging

# Define an async function to wait for button click
async def wait_for_click(button):
    # Create a future object
    future = asyncio.Future()
    # Define the click event handler
    def on_button_clicked(b):
        future.set_result(None)
    # Attach the event handler to the button
    button.on_click(on_button_clicked)
    # Wait until the future is set
    await future

class Points():
    def __init__(self, pixel_key, img, coordinates_path, size_multiplier=1):
        logging.getLogger().setLevel(logging.DEBUG)
        logging.info("Starting the Points class")
        self.img = img
        self.size_multiplier = size_multiplier
        self.coordinates_path = coordinates_path
        self.pixel_key = pixel_key

        # Save the image to a bytes buffer
        image = Image.fromarray(self.img)
        size = img.shape
        image = image.resize((size[1] * self.size_multiplier, size[0] * self.size_multiplier))
        buffer = io.BytesIO()
        image.save(buffer, format='PNG')
        buffer.seek(0)

        # Create an IPyWidgets Image widget
        self.canvas = Canvas(width=size[1] * self.size_multiplier, height=size[0] * self.size_multiplier)
        # Define the size of each cell

        self.canvas.put_image_data(np.array(image), 0, 0)

        # Display coordinates
        coords_label = widgets.Label(value="Click on the image to select the coordinates")

        # Define the click event handler
        self.coords = []
        def on_click(x, y)
            coords_label.value = f"Coordinates: ({x}, {y})"
            self.coords.append((0, x, y))

            with hold_canvas(self.canvas):
                self.canvas.put_image_data(np.array(image), 0, 0)  # Redraw the original image

                self.canvas.fill_style = 'red'
                for coord in self.coords:
                    x, y = coord[1] // self.size_multiplier, coord[2] // self.size_multiplier
                    self.canvas.fill_circle(x, y, 2)

        # Connect the click event to the handler
        self.canvas.on_mouse_down(on_click)

        self.button = widgets.Button(description="Save Points")

        # Display the widgets
        self.vbox = widgets.VBox([self.canvas, coords_label, self.button])

        # # Display the widget
        display(self.vbox)

    def on_done(self):
        logging.info("saving")
        Path(self.coordinates_path + "/coords/").mkdir(parents=True, exist_ok=True)
        with open(self.coordinates_path + "/coords/" + f"{self.pixel_key}_{object_name}" + ".pkl", 'wb') as f:
            try:
                pickle.dump(self.coords, f)
            except Exception as e:
                logging.info(e)
        Path(self.coordinates_path + "/images/").mkdir(parents=True, exist_ok=True)
        with open(self.coordinates_path + "/images/" + f"{self.pixel_key}" + ".png", 'wb') as f:
            try:
                image = Image.fromarray(self.img)
                image.save(f)
            except Exception as e:
                logging.info(e)
        logging.info("saved")

# %%
# NOTE: Label points for each pixel key. Make sure the order 
# of points is the same across pixel keys.
pixel_key = "pixels2"
    
with open(pickle_path, 'rb') as f:
    data = pickle.load(f)
img = data['observations'][traj_idx][pixel_key][0]
use_video = False
if original_bgr:
    img = img[:,:,::-1]        

async def f():
    point = Points(pixel_key, img, coordinates_path, size_multiplier)
    x = await wait_for_click(point.button)
    point.vbox.close()
    point.canvas.close()
    point.on_done()
asyncio.ensure_future(f())
# Out:
# <Task pending name='Task-5' coro=<f() running at /tmp/ipykernel_1491602/819368655.py:12>>
# INFO:root:Starting the Points class
# VBox(children=(Canvas(height=256, width=256), Label(value='Click on the image to select the coordinates'), But…
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 26, 607000, tzinfo=tzutc()), 'msg_id': '5af9a1f8-6048-4ca7-879b-e613b437dd9a', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': '5af9a1f8-6048-4ca7-879b-e613b437dd9a', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'client_ready'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 239000, tzinfo=tzutc()), 'msg_id': '12b56454-23f5-4797-9678-55b3b974dc59', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': '12b56454-23f5-4797-9678-55b3b974dc59', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': 0, 'y': 1}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 255000, tzinfo=tzutc()), 'msg_id': '3b116dcd-43e2-4960-b9ab-44a35f38a4fa', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': '3b116dcd-43e2-4960-b9ab-44a35f38a4fa', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': -1, 'y': 4}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 271000, tzinfo=tzutc()), 'msg_id': '3b4f3650-ced4-4948-ac87-b75ec749ac02', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': '3b4f3650-ced4-4948-ac87-b75ec749ac02', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': -1, 'y': 11}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 291000, tzinfo=tzutc()), 'msg_id': '2110f012-c081-4f66-8b2d-4615ff9dbbad', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': '2110f012-c081-4f66-8b2d-4615ff9dbbad', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': -2, 'y': 28}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 308000, tzinfo=tzutc()), 'msg_id': 'f7d570b4-c6c2-465e-b3af-c877d8c7bec6', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': 'f7d570b4-c6c2-465e-b3af-c877d8c7bec6', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': -2, 'y': 46}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 325000, tzinfo=tzutc()), 'msg_id': '0f3a46b6-064c-479d-bb68-d7725fad8305', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': '0f3a46b6-064c-479d-bb68-d7725fad8305', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': -3, 'y': 53}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 342000, tzinfo=tzutc()), 'msg_id': '96f86ca8-1834-461d-ba55-d117940c1309', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': '96f86ca8-1834-461d-ba55-d117940c1309', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': -4, 'y': 45}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 358000, tzinfo=tzutc()), 'msg_id': '972c7c2f-93a7-4635-8d30-c0a632f2ae66', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': '972c7c2f-93a7-4635-8d30-c0a632f2ae66', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': -4, 'y': 33}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 375000, tzinfo=tzutc()), 'msg_id': 'a0de57b5-d016-48ec-87bb-51de01c90710', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': 'a0de57b5-d016-48ec-87bb-51de01c90710', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': -4, 'y': 21}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 391000, tzinfo=tzutc()), 'msg_id': '71fc257b-83da-405b-be08-791bfac6be0b', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': '71fc257b-83da-405b-be08-791bfac6be0b', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': -2, 'y': 11}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 408000, tzinfo=tzutc()), 'msg_id': '00dc82f7-45d2-4a23-af3b-346217de1be9', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id': '00dc82f7-45d2-4a23-af3b-346217de1be9', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '081548cb02604412945cd5fec561d052', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': -2, 'y': 9}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[081548cb02604412945cd5fec561d052]({'header': {'date': datetime.datetime(2025, 6, 23, 4, 52, 27, 425000, tzinfo=tzutc()), 'msg_id': '4e604967-32f5-40aa-8c68-ce18ba6924a5', 'msg_type': 'comm_msg', 'session': '1b1f122b-a12c-4f3e-b070-b4567219f1a1', 'username': '9647c79f-9387-4acc-8f07-1286375b084f', 'version': '5.2'}, 'msg_id':